# %%
import numpy as np
import pandas as pd
import matplotlib
import seaborn as sb

# %%
data = pd.read_csv('states/Florida.csv')

# %%
data = data.loc[:316]

# %%
data = data.T

# %%
data.columns = data.loc['Title']

# %%
data
# Out:
# Title                 Total population          Male        Female  \
# Topic                           People        People        People
# Subject                    Sex and Age   Sex and Age   Sex and Age
# Title                 Total population          Male        Female
# District 01 Estimate            762506        384615        377891
# District 01 MOE            (+/- 1571 )   (+/- 2002 )   (+/- 1929 )
# District 02 Estimate            720418        369218        351200
# District 02 MOE            (+/- 9374 )   (+/- 6301 )   (+/- 5914 )
# District 03 Estimate            732088        363650        368438
# District 03 MOE            (+/- 6986 )   (+/- 4757 )   (+/- 4606 )
# District 04 Estimate            778620        381806        396814
# District 04 MOE           (+/- 11856 )   (+/- 7018 )   (+/- 7242 )
# District 05 Estimate            728346        352183        376163
# District 05 MOE           (+/- 12994 )   (+/- 7951 )   (+/- 7883 )
# ...
